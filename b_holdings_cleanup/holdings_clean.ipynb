# %% [markdown]
# ## holdings_clean.ipynb - Holdings file Clean
#
# by Tarak Patel
#
# This is Jupyter Notebook cleanup for 5 Portfolio holdings excel file donloaded from  https://individuals.voya.com/product/variable-portfolio/holdings/monthly
#
# Combining all the df into one df to upload to SQL

# %%
# Dependencies and Setup
import pandas as pd
import numpy as ny

# Pull data 
data_index_LC = "../a_source_data/voya-index-plus-largecap-portfolio-monthly-holdings-xls.xls"

# Read and store into Pandas data frame
read_index_LC = pd.read_excel(data_index_LC, skiprows=3)

index_LC_df = read_index_LC.dropna()
index_LC_df['fund_name'] = 'Voya Index Plus LargeCap Portfolio'
index_LC_df
# Out:
# WARNING *** file size (49088) not 512 + multiple of sector size (512)
# <ipython-input-2-265922fa13c7>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   index_LC_df['fund_name'] = 'Voya Index Plus LargeCap Portfolio'
#     Ticker                 Security Name Crncy        Country   Price  \
# 0     TWOU                      2U, Inc.   USD  United States   39.25
# 1      ABT           Abbott Laboratories   USD  United States  120.08
# 2     ABBV                  AbbVie, Inc.   USD  United States  111.50
# 3     ACAD  Acadia Pharmaceuticals, Inc.   USD  United States   20.56
# 4      ACN                 Accenture PLC   USD  United States  289.97
# ..     ...                           ...   ...            ...     ...
# 271   XLNX                  Xilinx, Inc.   USD  United States  127.96
# 272   YELP                    Yelp, Inc.   USD  United States   39.30
# 273   YETI           YETI Holdings, Inc.   USD  United States   85.42
# 274    YUM             Yum! Brands, Inc.   USD  United States  119.52
# 275    ZTS                  Zoetis, Inc.   USD  United States  173.03
#
#      Quantity  Market Value                           fund_name
# 0     13298.0     521946.50  Voya Index Plus LargeCap Portfolio
# 1     41778.0    5016702.24  Voya Index Plus LargeCap Portfolio
# 2     20026.0    2232899.00  Voya Index Plus LargeCap Portfolio
# 3     17198.0     353590.88  Voya Index Plus LargeCap Portfolio
# 4      4271.0    1238461.87  Voya Index Plus LargeCap Portfolio
# ..        ...           ...                                 ...
# 271   11220.0    1435711.20  Voya Index Plus LargeCap Portfolio
# 272   14020.0     550986.00  Voya Index Plus LargeCap Portfolio
# 273    8131.0     694550.02  Voya Index Plus LargeCap Portfolio
# 274   37171.0    4442677.92  Voya Index Plus LargeCap Portfolio
# 275   18860.0    3263345.80  Voya Index Plus LargeCap Portfolio
#
# [274 rows x 8 columns]

# %%
# Pull data 
data_LCG = "../a_source_data/voya-large-cap-growth-portfolio-monthly-holdings-xls.xls"

# Read and store into Pandas data frame
read_LCG = pd.read_excel(data_LCG, skiprows=3)

LCG_df = read_LCG.dropna()
LCG_df['fund_name'] = 'Voya LargeCap Growth Portfolio'
LCG_df
# Out:
# WARNING *** file size (16320) not 512 + multiple of sector size (512)
# <ipython-input-3-bcfb62807237>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LCG_df['fund_name'] = 'Voya LargeCap Growth Portfolio'
#    Ticker                                      Security Name Crncy  \
# 0     AMD                       Advanced Micro Devices, Inc.   USD
# 1       A                         Agilent Technologies, Inc.   USD
# 2     APD                     Air Products & Chemicals, Inc.   USD
# 3    ALGN                             Align Technology, Inc.   USD
# 4   GOOGL                           Alphabet, Inc. - Class A   USD
# 5    AMZN                                   Amazon.com, Inc.   USD
# 6     AME                                       Ametek, Inc.   USD
# 7    AAPL                                        Apple, Inc.   USD
# 8    ADSK                                     Autodesk, Inc.   USD
# 10  TFDXX  BlackRock Liquidity Funds, FedFund, Institutio...   USD
# 11   COIN                              Coinbase Global, Inc.   USD
# 12    STZ                         Constellation Brands, Inc.   USD
# 13   CSGP                                 CoStar Group, Inc.   USD
# 14    CCK                               Crown Holdings, Inc.   USD
# 15    CSX                                          CSX Corp.   USD
# 16    DHR                                      Danaher Corp.   USD
# 17    DRI                           Darden Restaurants, Inc.   USD
# 18   DXCM                                       DexCom, Inc.   USD
# 19    ETN                                    Eaton Corp. PLC   USD
# 20    LLY                                    Eli Lilly & Co.   USD
# 21   ENTG                                     Entegris, Inc.   USD
# 22   EXAS                               Exact Sciences Corp.   USD
# 23   EXPE                                Expedia Group, Inc.   USD
# 24     FB                            Facebook, Inc.- Class A   USD
# 25   FIVN                                        Five9, Inc.   USD
# 26   HZNP                           Horizon Therapeutics Plc   USD
# 27   INTU                                       Intuit, Inc.   USD
# 28   LRCX                                 Lam Research Corp.   USD
# 29   LULU                          Lululemon Athletica, Inc.   USD
# 30   MRVL                           Marvell Technology, Inc.   USD
# 31     MA                         Mastercard, Inc. - Class A   USD
# 32   MSFT                                    Microsoft Corp.   USD
# 33   MPWR                     Monolithic Power Systems, Inc.   USD
# 34   MSCI                               MSCI, Inc. - Class A   USD
# 35   NVDA                                       Nvidia Corp.   USD
# 36   ORLY                          O'Reilly Automotive, Inc.   USD
# 37   PAYC                              Paycom Software, Inc.   USD
# 38   PYPL                              PayPal Holdings, Inc.   USD
# 39     PM                  Philip Morris International, Inc.   USD
# 40   QCOM                                     Qualcomm, Inc.   USD
# 41    PWR                              Quanta Services, Inc.   USD
# 42    RNG                                  RingCentral, Inc.   USD
# 43   ROST                                  Ross Stores, Inc.   USD
# 44   SBAC                           SBA Communications Corp.   USD
# 45    NOW                                   ServiceNow, Inc.   USD
# 46   SNAP                                         Snap, Inc.   USD
# 47   SPOT                              Spotify Technology SA   USD
# 48   TTWO                Take-Two Interactive Software, Inc.   USD
# 49   TNDM                         Tandem Diabetes Care, Inc.   USD
# 50   TWLO                                       Twilio, Inc.   USD
# 51   VEEV                                Veeva Systems, Inc.   USD
# 52      V                               Visa, Inc. - Class A   USD
# 53    WCN                            Waste Connections, Inc.   USD
# 54   ZBRA                           Zebra Technologies Corp.   USD
#
#           Country    Price    Quantity  Market Value  \
# 0   United States    81.62   1788568.0  1.459829e+08
# 1   United States   133.64    528065.0  7.057061e+07
# 2   United States   288.48    232720.0  6.713507e+07
# 3   United States   595.53    112431.0  6.695603e+07
# 4   United States  2353.50     16848.0  3.965177e+07
# 5   United States  3467.42    185998.0  6.449332e+08
# 6   United States   134.93    492010.0  6.638691e+07
# 7   United States   131.46   4045133.0  5.317732e+08
# 8   United States   291.91    351218.0  1.025240e+08
# 10  United States     1.00  20922000.0  2.092200e+07
# 11  United States   297.64     94612.0  2.816032e+07
# 12  United States   240.32    446661.0  1.073416e+08
# 13  United States   854.43     44658.0  3.815713e+07
# 14  United States   109.80    546493.0  6.000493e+07
# 15  United States   100.75    999902.0  1.007401e+08
# 16  United States   253.94    531422.0  1.349493e+08
# 17  United States   146.72    572735.0  8.403168e+07
# 18  United States   386.10    214837.0  8.294857e+07
# 19  United States   142.93    530334.0  7.580064e+07
# 20  United States   182.77   1084218.0  1.981625e+08
# 21  United States   112.58    637083.0  7.172280e+07
# 22  United States   131.82    473443.0  6.240926e+07
# 23  United States   176.23    670984.0  1.182475e+08
# 24  United States   325.08   1386878.0  4.508463e+08
# 25  United States   187.97    253497.0  4.764983e+07
# 26  United States    94.62    957311.0  9.058077e+07
# 27  United States   412.16    547061.0  2.254767e+08
# 28  United States   620.45    175664.0  1.089907e+08
# 29         Canada   335.27    251288.0  8.424933e+07
# 30  United States    45.21   1725626.0  7.801555e+07
# 31  United States   382.06     79868.0  3.051437e+07
# 32  United States   252.18   1239037.0  3.124604e+08
# 33  United States   361.38    105948.0  3.828749e+07
# 34  United States   485.77    191687.0  9.311579e+07
# 35  United States   600.38    203945.0  1.224445e+08
# 36  United States   552.88    221075.0  1.222279e+08
# 37  United States   384.41    298466.0  1.147333e+08
# 38  United States   262.29    817723.0  2.144806e+08
# 39  United States    95.00   1624131.0  1.542924e+08
# 40  United States   138.80    965224.0  1.339731e+08
# 41  United States    96.64    372055.0  3.595540e+07
# 42  United States   318.95    175102.0  5.584878e+07
# 43  United States   130.94    993942.0  1.301468e+08
# 44  United States   299.72    265929.0  7.970424e+07
# 45  United States   506.37    128827.0  6.523413e+07
# 46  United States    61.82   1619628.0  1.001254e+08
# 47         Sweden   252.12    237715.0  5.993271e+07
# 48  United States   175.38    587215.0  1.029858e+08
# 49  United States    91.90    323080.0  2.969105e+07
# 50  United States   367.80    184701.0  6.793303e+07
# 51  United States   282.45    169864.0  4.797809e+07
# 52  United States   233.56   1382460.0  3.228874e+08
# 53         Canada   119.11    407720.0  4.856353e+07
# 54  United States   487.74     88944.0  4.338155e+07
#
#                          fund_name
# 0   Voya LargeCap Growth Portfolio
# 1   Voya LargeCap Growth Portfolio
# 2   Voya LargeCap Growth Portfolio
# 3   Voya LargeCap Growth Portfolio
# 4   Voya LargeCap Growth Portfolio
# 5   Voya LargeCap Growth Portfolio
# 6   Voya LargeCap Growth Portfolio
# 7   Voya LargeCap Growth Portfolio
# 8   Voya LargeCap Growth Portfolio
# 10  Voya LargeCap Growth Portfolio
# 11  Voya LargeCap Growth Portfolio
# 12  Voya LargeCap Growth Portfolio
# 13  Voya LargeCap Growth Portfolio
# 14  Voya LargeCap Growth Portfolio
# 15  Voya LargeCap Growth Portfolio
# 16  Voya LargeCap Growth Portfolio
# 17  Voya LargeCap Growth Portfolio
# 18  Voya LargeCap Growth Portfolio
# 19  Voya LargeCap Growth Portfolio
# 20  Voya LargeCap Growth Portfolio
# 21  Voya LargeCap Growth Portfolio
# 22  Voya LargeCap Growth Portfolio
# 23  Voya LargeCap Growth Portfolio
# 24  Voya LargeCap Growth Portfolio
# 25  Voya LargeCap Growth Portfolio
# 26  Voya LargeCap Growth Portfolio
# 27  Voya LargeCap Growth Portfolio
# 28  Voya LargeCap Growth Portfolio
# 29  Voya LargeCap Growth Portfolio
# 30  Voya LargeCap Growth Portfolio
# 31  Voya LargeCap Growth Portfolio
# 32  Voya LargeCap Growth Portfolio
# 33  Voya LargeCap Growth Portfolio
# 34  Voya LargeCap Growth Portfolio
# 35  Voya LargeCap Growth Portfolio
# 36  Voya LargeCap Growth Portfolio
# 37  Voya LargeCap Growth Portfolio
# 38  Voya LargeCap Growth Portfolio
# 39  Voya LargeCap Growth Portfolio
# 40  Voya LargeCap Growth Portfolio
# 41  Voya LargeCap Growth Portfolio
# 42  Voya LargeCap Growth Portfolio
# 43  Voya LargeCap Growth Portfolio
# 44  Voya LargeCap Growth Portfolio
# 45  Voya LargeCap Growth Portfolio
# 46  Voya LargeCap Growth Portfolio
# 47  Voya LargeCap Growth Portfolio
# 48  Voya LargeCap Growth Portfolio
# 49  Voya LargeCap Growth Portfolio
# 50  Voya LargeCap Growth Portfolio
# 51  Voya LargeCap Growth Portfolio
# 52  Voya LargeCap Growth Portfolio
# 53  Voya LargeCap Growth Portfolio
# 54  Voya LargeCap Growth Portfolio

# %%
# Pull data 
data_LCV = "../a_source_data/voya-large-cap-value-portfolio-monthly-holdings-xls.xls"

# Read and store into Pandas data frame
read_LCV = pd.read_excel(data_LCV, skiprows=3)

LCV_df = read_LCV.dropna()
LCV_df['fund_name'] = 'Voya LargeCap Value Portfolio'
LCV_df
# Out:
# <ipython-input-4-b6f1e5c475da>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LCV_df['fund_name'] = 'Voya LargeCap Value Portfolio'
#    Ticker                   Security Name Crncy        Country    Price  \
# 0    ATVI       Activision Blizzard, Inc.   USD  United States    91.19
# 1     APD  Air Products & Chemicals, Inc.   USD  United States   288.48
# 2      AA                     Alcoa Corp.   USD  United States    36.64
# 3     ALC                     Alcon, Inc.   USD    Switzerland    75.43
# 4   GOOGL        Alphabet, Inc. - Class A   USD  United States  2353.50
# ..    ...                             ...   ...            ...      ...
# 75    USB                      US Bancorp   USD  United States    59.35
# 76    VLO             Valero Energy Corp.   USD  United States    73.96
# 77    WMT                   Walmart, Inc.   USD  United States   139.91
# 78    DIS                 Walt Disney Co.   USD  United States   186.02
# 79    ZBH    Zimmer Biomet Holdings, Inc.   USD  United States   177.16
#
#     Quantity  Market Value                      fund_name
# 0   161140.0   14694356.60  Voya LargeCap Value Portfolio
# 1    33170.0    9568881.60  Voya LargeCap Value Portfolio
# 2   174772.0    6403646.08  Voya LargeCap Value Portfolio
# 3   139551.0   10526331.93  Voya LargeCap Value Portfolio
# 4    10871.0   25584898.50  Voya LargeCap Value Portfolio
# ..       ...           ...                            ...
# 75  560122.0   33243240.70  Voya LargeCap Value Portfolio
# 76  153701.0   11367725.96  Voya LargeCap Value Portfolio
# 77  158104.0   22120330.64  Voya LargeCap Value Portfolio
# 78  171542.0   31910242.84  Voya LargeCap Value Portfolio
# 79  108639.0   19246485.24  Voya LargeCap Value Portfolio
#
# [74 rows x 8 columns]

# %%
# Pull data 
data_RLC = "../a_source_data/voya-russell-large-cap-index-portfolio-monthly-holdings-xls.xls"

# Read and store into Pandas data frame
read_RLC = pd.read_excel(data_RLC, skiprows=3)

RLC_df = read_RLC.dropna()
RLC_df['fund_name'] = 'Voya Russell LargeCap Index Portfolio'
RLC_df
# Out:
# WARNING *** file size (40896) not 512 + multiple of sector size (512)
# <ipython-input-5-abe0e8fcda84>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RLC_df['fund_name'] = 'Voya Russell LargeCap Index Portfolio'
#     Ticker                    Security Name Crncy        Country   Price  \
# 0      MMM                           3M Co.   USD  United States  197.14
# 1      ABT              Abbott Laboratories   USD  United States  120.08
# 2     ABBV                     AbbVie, Inc.   USD  United States  111.50
# 3      ACN                    Accenture PLC   USD  United States  289.97
# 4     ATVI        Activision Blizzard, Inc.   USD  United States   91.19
# ..     ...                              ...   ...            ...     ...
# 193    WFC                Wells Fargo & Co.   USD  United States   45.05
# 194   WDAY                    Workday, Inc.   USD  United States  247.00
# 195    YUM                Yum! Brands, Inc.   USD  United States  119.52
# 196    ZTS                     Zoetis, Inc.   USD  United States  173.03
# 197     ZM  Zoom Video Communications, Inc.   USD  United States  319.57
#
#      Quantity  Market Value                              fund_name
# 0     24044.0    4740034.16  Voya Russell LargeCap Index Portfolio
# 1     73961.0    8881236.88  Voya Russell LargeCap Index Portfolio
# 2     75380.0    8404870.00  Voya Russell LargeCap Index Portfolio
# 3     27274.0    7908641.78  Voya Russell LargeCap Index Portfolio
# 4     32654.0    2977718.26  Voya Russell LargeCap Index Portfolio
# ..        ...           ...                                    ...
# 193  162386.0    7315489.30  Voya Russell LargeCap Index Portfolio
# 194    7653.0    1890291.00  Voya Russell LargeCap Index Portfolio
# 195   12879.0    1539298.08  Voya Russell LargeCap Index Portfolio
# 196   20335.0    3518565.05  Voya Russell LargeCap Index Portfolio
# 197    7486.0    2392301.02  Voya Russell LargeCap Index Portfolio
#
# [196 rows x 8 columns]

# %%
# Pull data 
data_USSI = "../a_source_data/voya-us-stock-index-portfolio-monthly-holdings-xls.xls"

# Read and store into Pandas data frame
read_USSI = pd.read_excel(data_USSI, skiprows=3)

USSI_df = read_USSI.dropna()
USSI_df['fund_name'] = 'Voya U.S. Stock Index Portfolio'
USSI_df
# Out:
# WARNING *** file size (90048) not 512 + multiple of sector size (512)
# <ipython-input-6-f982a1d39d51>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   USSI_df['fund_name'] = 'Voya U.S. Stock Index Portfolio'
#     Ticker                 Security Name Crncy        Country   Price  \
# 0      MMM                        3M Co.   USD  United States  197.14
# 1      ABT           Abbott Laboratories   USD  United States  120.08
# 2     ABBV                  AbbVie, Inc.   USD  United States  111.50
# 3     ABMD                 Abiomed, Inc.   USD  United States  320.73
# 4      ACN                 Accenture PLC   USD  United States  289.97
# ..     ...                           ...   ...            ...     ...
# 502    YUM             Yum! Brands, Inc.   USD  United States  119.52
# 503   ZBRA      Zebra Technologies Corp.   USD  United States  487.74
# 504    ZBH  Zimmer Biomet Holdings, Inc.   USD  United States  177.16
# 505   ZION              Zions Bancorp NA   USD  United States   55.80
# 506    ZTS                  Zoetis, Inc.   USD  United States  173.03
#
#      Quantity  Market Value                        fund_name
# 0    128379.0   25308636.06  Voya U.S. Stock Index Portfolio
# 1    392724.0   47158297.92  Voya U.S. Stock Index Portfolio
# 2    391473.0   43649239.50  Voya U.S. Stock Index Portfolio
# 3     10027.0    3215959.71  Voya U.S. Stock Index Portfolio
# 4    140604.0   40770941.88  Voya U.S. Stock Index Portfolio
# ..        ...           ...                              ...
# 502   66518.0    7950231.36  Voya U.S. Stock Index Portfolio
# 503   11853.0    5781182.22  Voya U.S. Stock Index Portfolio
# 504   46079.0    8163355.64  Voya U.S. Stock Index Portfolio
# 505   36404.0    2031343.20  Voya U.S. Stock Index Portfolio
# 506  105338.0   18226634.14  Voya U.S. Stock Index Portfolio
#
# [506 rows x 8 columns]

# %%
# Use concate function to combine all dataframes.

df = pd.concat([index_LC_df, LCG_df, LCV_df, RLC_df, USSI_df])


# Column Names Clean up

df_final = df.rename(columns={'Ticker': 'ticker',
                     'Security Name' : 'security_name',
                     'Crncy' : 'currency',
                     'Country' : 'country',
                     'Price' : 'price',
                     'Quantity' : 'quantity',
                     'Market Value' : 'market_value',
                      })

df_final.set_index('ticker')

df_final.to_csv('fund_holdings.csv')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1104 entries, 0 to 506
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ticker         1104 non-null   object
#  1   security_name  1104 non-null   object
#  2   currency       1104 non-null   object
#  3   country        1104 non-null   object
#  4   price          1104 non-null   float64
#  5   quantity       1104 non-null   float64
#  6   market_value   1104 non-null   float64
#  7   fund_name      1104 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 77.6+ KB

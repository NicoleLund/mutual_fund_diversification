# %% [markdown]
# ## holdings_clean.ipynb - Holdings file Clean
#
# by Tarak Patel
#
# This is Jupyter Notebook cleanup for 5 Portfolio holdings excel file donloaded from  https://individuals.voya.com/product/variable-portfolio/holdings/monthly
#
# Combining all the df into one df to upload to SQL

# %%
# Dependencies and Setup
import pandas as pd
import numpy as ny

# Pull data 
data_index_LC = "../a_source_data/voya-index-plus-largecap-portfolio-monthly-holdings-xls.xls"

# Read and store into Pandas data frame
read_index_LC = pd.read_excel(data_index_LC, skiprows=3)

index_LC_df = read_index_LC.dropna()
# index_LC_df['fund_name'] = 'Voya Index Plus LargeCap Portfolio'
index_LC_df.insert(0, 'fund_name', 'Voya Index Plus LargeCap Portfolio')
index_LC_df
# Out:
# WARNING *** file size (49088) not 512 + multiple of sector size (512)
#                               fund_name Ticker                 Security Name  \
# 0    Voya Index Plus LargeCap Portfolio   TWOU                      2U, Inc.
# 1    Voya Index Plus LargeCap Portfolio    ABT           Abbott Laboratories
# 2    Voya Index Plus LargeCap Portfolio   ABBV                  AbbVie, Inc.
# 3    Voya Index Plus LargeCap Portfolio   ACAD  Acadia Pharmaceuticals, Inc.
# 4    Voya Index Plus LargeCap Portfolio    ACN                 Accenture PLC
# ..                                  ...    ...                           ...
# 271  Voya Index Plus LargeCap Portfolio   XLNX                  Xilinx, Inc.
# 272  Voya Index Plus LargeCap Portfolio   YELP                    Yelp, Inc.
# 273  Voya Index Plus LargeCap Portfolio   YETI           YETI Holdings, Inc.
# 274  Voya Index Plus LargeCap Portfolio    YUM             Yum! Brands, Inc.
# 275  Voya Index Plus LargeCap Portfolio    ZTS                  Zoetis, Inc.
#
#     Crncy        Country   Price  Quantity  Market Value
# 0     USD  United States   39.25   13298.0     521946.50
# 1     USD  United States  120.08   41778.0    5016702.24
# 2     USD  United States  111.50   20026.0    2232899.00
# 3     USD  United States   20.56   17198.0     353590.88
# 4     USD  United States  289.97    4271.0    1238461.87
# ..    ...            ...     ...       ...           ...
# 271   USD  United States  127.96   11220.0    1435711.20
# 272   USD  United States   39.30   14020.0     550986.00
# 273   USD  United States   85.42    8131.0     694550.02
# 274   USD  United States  119.52   37171.0    4442677.92
# 275   USD  United States  173.03   18860.0    3263345.80
#
# [274 rows x 8 columns]

# %%
# Pull data 
data_LCG = "../a_source_data/voya-large-cap-growth-portfolio-monthly-holdings-xls.xls"

# Read and store into Pandas data frame
read_LCG = pd.read_excel(data_LCG, skiprows=3)

LCG_df = read_LCG.dropna()
# LCG_df['fund_name'] = 'Voya LargeCap Growth Portfolio'
LCG_df.insert(0, 'fund_name', 'Voya LargeCap Growth Portfolio')
LCG_df
# Out:
# WARNING *** file size (16320) not 512 + multiple of sector size (512)
#                          fund_name Ticker  \
# 0   Voya LargeCap Growth Portfolio    AMD
# 1   Voya LargeCap Growth Portfolio      A
# 2   Voya LargeCap Growth Portfolio    APD
# 3   Voya LargeCap Growth Portfolio   ALGN
# 4   Voya LargeCap Growth Portfolio  GOOGL
# 5   Voya LargeCap Growth Portfolio   AMZN
# 6   Voya LargeCap Growth Portfolio    AME
# 7   Voya LargeCap Growth Portfolio   AAPL
# 8   Voya LargeCap Growth Portfolio   ADSK
# 10  Voya LargeCap Growth Portfolio  TFDXX
# 11  Voya LargeCap Growth Portfolio   COIN
# 12  Voya LargeCap Growth Portfolio    STZ
# 13  Voya LargeCap Growth Portfolio   CSGP
# 14  Voya LargeCap Growth Portfolio    CCK
# 15  Voya LargeCap Growth Portfolio    CSX
# 16  Voya LargeCap Growth Portfolio    DHR
# 17  Voya LargeCap Growth Portfolio    DRI
# 18  Voya LargeCap Growth Portfolio   DXCM
# 19  Voya LargeCap Growth Portfolio    ETN
# 20  Voya LargeCap Growth Portfolio    LLY
# 21  Voya LargeCap Growth Portfolio   ENTG
# 22  Voya LargeCap Growth Portfolio   EXAS
# 23  Voya LargeCap Growth Portfolio   EXPE
# 24  Voya LargeCap Growth Portfolio     FB
# 25  Voya LargeCap Growth Portfolio   FIVN
# 26  Voya LargeCap Growth Portfolio   HZNP
# 27  Voya LargeCap Growth Portfolio   INTU
# 28  Voya LargeCap Growth Portfolio   LRCX
# 29  Voya LargeCap Growth Portfolio   LULU
# 30  Voya LargeCap Growth Portfolio   MRVL
# 31  Voya LargeCap Growth Portfolio     MA
# 32  Voya LargeCap Growth Portfolio   MSFT
# 33  Voya LargeCap Growth Portfolio   MPWR
# 34  Voya LargeCap Growth Portfolio   MSCI
# 35  Voya LargeCap Growth Portfolio   NVDA
# 36  Voya LargeCap Growth Portfolio   ORLY
# 37  Voya LargeCap Growth Portfolio   PAYC
# 38  Voya LargeCap Growth Portfolio   PYPL
# 39  Voya LargeCap Growth Portfolio     PM
# 40  Voya LargeCap Growth Portfolio   QCOM
# 41  Voya LargeCap Growth Portfolio    PWR
# 42  Voya LargeCap Growth Portfolio    RNG
# 43  Voya LargeCap Growth Portfolio   ROST
# 44  Voya LargeCap Growth Portfolio   SBAC
# 45  Voya LargeCap Growth Portfolio    NOW
# 46  Voya LargeCap Growth Portfolio   SNAP
# 47  Voya LargeCap Growth Portfolio   SPOT
# 48  Voya LargeCap Growth Portfolio   TTWO
# 49  Voya LargeCap Growth Portfolio   TNDM
# 50  Voya LargeCap Growth Portfolio   TWLO
# 51  Voya LargeCap Growth Portfolio   VEEV
# 52  Voya LargeCap Growth Portfolio      V
# 53  Voya LargeCap Growth Portfolio    WCN
# 54  Voya LargeCap Growth Portfolio   ZBRA
#
#                                         Security Name Crncy        Country  \
# 0                        Advanced Micro Devices, Inc.   USD  United States
# 1                          Agilent Technologies, Inc.   USD  United States
# 2                      Air Products & Chemicals, Inc.   USD  United States
# 3                              Align Technology, Inc.   USD  United States
# 4                            Alphabet, Inc. - Class A   USD  United States
# 5                                    Amazon.com, Inc.   USD  United States
# 6                                        Ametek, Inc.   USD  United States
# 7                                         Apple, Inc.   USD  United States
# 8                                      Autodesk, Inc.   USD  United States
# 10  BlackRock Liquidity Funds, FedFund, Institutio...   USD  United States
# 11                              Coinbase Global, Inc.   USD  United States
# 12                         Constellation Brands, Inc.   USD  United States
# 13                                 CoStar Group, Inc.   USD  United States
# 14                               Crown Holdings, Inc.   USD  United States
# 15                                          CSX Corp.   USD  United States
# 16                                      Danaher Corp.   USD  United States
# 17                           Darden Restaurants, Inc.   USD  United States
# 18                                       DexCom, Inc.   USD  United States
# 19                                    Eaton Corp. PLC   USD  United States
# 20                                    Eli Lilly & Co.   USD  United States
# 21                                     Entegris, Inc.   USD  United States
# 22                               Exact Sciences Corp.   USD  United States
# 23                                Expedia Group, Inc.   USD  United States
# 24                            Facebook, Inc.- Class A   USD  United States
# 25                                        Five9, Inc.   USD  United States
# 26                           Horizon Therapeutics Plc   USD  United States
# 27                                       Intuit, Inc.   USD  United States
# 28                                 Lam Research Corp.   USD  United States
# 29                          Lululemon Athletica, Inc.   USD         Canada
# 30                           Marvell Technology, Inc.   USD  United States
# 31                         Mastercard, Inc. - Class A   USD  United States
# 32                                    Microsoft Corp.   USD  United States
# 33                     Monolithic Power Systems, Inc.   USD  United States
# 34                               MSCI, Inc. - Class A   USD  United States
# 35                                       Nvidia Corp.   USD  United States
# 36                          O'Reilly Automotive, Inc.   USD  United States
# 37                              Paycom Software, Inc.   USD  United States
# 38                              PayPal Holdings, Inc.   USD  United States
# 39                  Philip Morris International, Inc.   USD  United States
# 40                                     Qualcomm, Inc.   USD  United States
# 41                              Quanta Services, Inc.   USD  United States
# 42                                  RingCentral, Inc.   USD  United States
# 43                                  Ross Stores, Inc.   USD  United States
# 44                           SBA Communications Corp.   USD  United States
# 45                                   ServiceNow, Inc.   USD  United States
# 46                                         Snap, Inc.   USD  United States
# 47                              Spotify Technology SA   USD         Sweden
# 48                Take-Two Interactive Software, Inc.   USD  United States
# 49                         Tandem Diabetes Care, Inc.   USD  United States
# 50                                       Twilio, Inc.   USD  United States
# 51                                Veeva Systems, Inc.   USD  United States
# 52                               Visa, Inc. - Class A   USD  United States
# 53                            Waste Connections, Inc.   USD         Canada
# 54                           Zebra Technologies Corp.   USD  United States
#
#       Price    Quantity  Market Value
# 0     81.62   1788568.0  1.459829e+08
# 1    133.64    528065.0  7.057061e+07
# 2    288.48    232720.0  6.713507e+07
# 3    595.53    112431.0  6.695603e+07
# 4   2353.50     16848.0  3.965177e+07
# 5   3467.42    185998.0  6.449332e+08
# 6    134.93    492010.0  6.638691e+07
# 7    131.46   4045133.0  5.317732e+08
# 8    291.91    351218.0  1.025240e+08
# 10     1.00  20922000.0  2.092200e+07
# 11   297.64     94612.0  2.816032e+07
# 12   240.32    446661.0  1.073416e+08
# 13   854.43     44658.0  3.815713e+07
# 14   109.80    546493.0  6.000493e+07
# 15   100.75    999902.0  1.007401e+08
# 16   253.94    531422.0  1.349493e+08
# 17   146.72    572735.0  8.403168e+07
# 18   386.10    214837.0  8.294857e+07
# 19   142.93    530334.0  7.580064e+07
# 20   182.77   1084218.0  1.981625e+08
# 21   112.58    637083.0  7.172280e+07
# 22   131.82    473443.0  6.240926e+07
# 23   176.23    670984.0  1.182475e+08
# 24   325.08   1386878.0  4.508463e+08
# 25   187.97    253497.0  4.764983e+07
# 26    94.62    957311.0  9.058077e+07
# 27   412.16    547061.0  2.254767e+08
# 28   620.45    175664.0  1.089907e+08
# 29   335.27    251288.0  8.424933e+07
# 30    45.21   1725626.0  7.801555e+07
# 31   382.06     79868.0  3.051437e+07
# 32   252.18   1239037.0  3.124604e+08
# 33   361.38    105948.0  3.828749e+07
# 34   485.77    191687.0  9.311579e+07
# 35   600.38    203945.0  1.224445e+08
# 36   552.88    221075.0  1.222279e+08
# 37   384.41    298466.0  1.147333e+08
# 38   262.29    817723.0  2.144806e+08
# 39    95.00   1624131.0  1.542924e+08
# 40   138.80    965224.0  1.339731e+08
# 41    96.64    372055.0  3.595540e+07
# 42   318.95    175102.0  5.584878e+07
# 43   130.94    993942.0  1.301468e+08
# 44   299.72    265929.0  7.970424e+07
# 45   506.37    128827.0  6.523413e+07
# 46    61.82   1619628.0  1.001254e+08
# 47   252.12    237715.0  5.993271e+07
# 48   175.38    587215.0  1.029858e+08
# 49    91.90    323080.0  2.969105e+07
# 50   367.80    184701.0  6.793303e+07
# 51   282.45    169864.0  4.797809e+07
# 52   233.56   1382460.0  3.228874e+08
# 53   119.11    407720.0  4.856353e+07
# 54   487.74     88944.0  4.338155e+07

# %%
# Pull data 
data_LCV = "../a_source_data/voya-large-cap-value-portfolio-monthly-holdings-xls.xls"

# Read and store into Pandas data frame
read_LCV = pd.read_excel(data_LCV, skiprows=3)

LCV_df = read_LCV.dropna()
# LCV_df['fund_name'] = 'Voya LargeCap Value Portfolio'
LCV_df.insert(0, 'fund_name', 'Voya LargeCap Value Portfolio')
LCV_df
# Out:
#                         fund_name Ticker                   Security Name  \
# 0   Voya LargeCap Value Portfolio   ATVI       Activision Blizzard, Inc.
# 1   Voya LargeCap Value Portfolio    APD  Air Products & Chemicals, Inc.
# 2   Voya LargeCap Value Portfolio     AA                     Alcoa Corp.
# 3   Voya LargeCap Value Portfolio    ALC                     Alcon, Inc.
# 4   Voya LargeCap Value Portfolio  GOOGL        Alphabet, Inc. - Class A
# ..                            ...    ...                             ...
# 75  Voya LargeCap Value Portfolio    USB                      US Bancorp
# 76  Voya LargeCap Value Portfolio    VLO             Valero Energy Corp.
# 77  Voya LargeCap Value Portfolio    WMT                   Walmart, Inc.
# 78  Voya LargeCap Value Portfolio    DIS                 Walt Disney Co.
# 79  Voya LargeCap Value Portfolio    ZBH    Zimmer Biomet Holdings, Inc.
#
#    Crncy        Country    Price  Quantity  Market Value
# 0    USD  United States    91.19  161140.0   14694356.60
# 1    USD  United States   288.48   33170.0    9568881.60
# 2    USD  United States    36.64  174772.0    6403646.08
# 3    USD    Switzerland    75.43  139551.0   10526331.93
# 4    USD  United States  2353.50   10871.0   25584898.50
# ..   ...            ...      ...       ...           ...
# 75   USD  United States    59.35  560122.0   33243240.70
# 76   USD  United States    73.96  153701.0   11367725.96
# 77   USD  United States   139.91  158104.0   22120330.64
# 78   USD  United States   186.02  171542.0   31910242.84
# 79   USD  United States   177.16  108639.0   19246485.24
#
# [74 rows x 8 columns]

# %%
# Pull data 
data_RLC = "../a_source_data/voya-russell-large-cap-index-portfolio-monthly-holdings-xls.xls"

# Read and store into Pandas data frame
read_RLC = pd.read_excel(data_RLC, skiprows=3)

RLC_df = read_RLC.dropna()
# RLC_df['fund_name'] = 'Voya Russell LargeCap Index Portfolio'
RLC_df.insert(0, 'fund_name', 'Voya Russell LargeCap Index Portfolio')
RLC_df
# Out:
# WARNING *** file size (40896) not 512 + multiple of sector size (512)
#                                  fund_name Ticker  \
# 0    Voya Russell LargeCap Index Portfolio    MMM
# 1    Voya Russell LargeCap Index Portfolio    ABT
# 2    Voya Russell LargeCap Index Portfolio   ABBV
# 3    Voya Russell LargeCap Index Portfolio    ACN
# 4    Voya Russell LargeCap Index Portfolio   ATVI
# ..                                     ...    ...
# 193  Voya Russell LargeCap Index Portfolio    WFC
# 194  Voya Russell LargeCap Index Portfolio   WDAY
# 195  Voya Russell LargeCap Index Portfolio    YUM
# 196  Voya Russell LargeCap Index Portfolio    ZTS
# 197  Voya Russell LargeCap Index Portfolio     ZM
#
#                        Security Name Crncy        Country   Price  Quantity  \
# 0                             3M Co.   USD  United States  197.14   24044.0
# 1                Abbott Laboratories   USD  United States  120.08   73961.0
# 2                       AbbVie, Inc.   USD  United States  111.50   75380.0
# 3                      Accenture PLC   USD  United States  289.97   27274.0
# 4          Activision Blizzard, Inc.   USD  United States   91.19   32654.0
# ..                               ...   ...            ...     ...       ...
# 193                Wells Fargo & Co.   USD  United States   45.05  162386.0
# 194                    Workday, Inc.   USD  United States  247.00    7653.0
# 195                Yum! Brands, Inc.   USD  United States  119.52   12879.0
# 196                     Zoetis, Inc.   USD  United States  173.03   20335.0
# 197  Zoom Video Communications, Inc.   USD  United States  319.57    7486.0
#
#      Market Value
# 0      4740034.16
# 1      8881236.88
# 2      8404870.00
# 3      7908641.78
# 4      2977718.26
# ..            ...
# 193    7315489.30
# 194    1890291.00
# 195    1539298.08
# 196    3518565.05
# 197    2392301.02
#
# [196 rows x 8 columns]

# %%
# Pull data 
data_USSI = "../a_source_data/voya-us-stock-index-portfolio-monthly-holdings-xls.xls"

# Read and store into Pandas data frame
read_USSI = pd.read_excel(data_USSI, skiprows=3)

USSI_df = read_USSI.dropna()
# USSI_df['fund_name'] = 'Voya U.S. Stock Index Portfolio'
USSI_df.insert(0, 'fund_name', 'Voya U.S. Stock Index Portfolio')
USSI_df
# Out:
# WARNING *** file size (90048) not 512 + multiple of sector size (512)
#                            fund_name Ticker                 Security Name  \
# 0    Voya U.S. Stock Index Portfolio    MMM                        3M Co.
# 1    Voya U.S. Stock Index Portfolio    ABT           Abbott Laboratories
# 2    Voya U.S. Stock Index Portfolio   ABBV                  AbbVie, Inc.
# 3    Voya U.S. Stock Index Portfolio   ABMD                 Abiomed, Inc.
# 4    Voya U.S. Stock Index Portfolio    ACN                 Accenture PLC
# ..                               ...    ...                           ...
# 502  Voya U.S. Stock Index Portfolio    YUM             Yum! Brands, Inc.
# 503  Voya U.S. Stock Index Portfolio   ZBRA      Zebra Technologies Corp.
# 504  Voya U.S. Stock Index Portfolio    ZBH  Zimmer Biomet Holdings, Inc.
# 505  Voya U.S. Stock Index Portfolio   ZION              Zions Bancorp NA
# 506  Voya U.S. Stock Index Portfolio    ZTS                  Zoetis, Inc.
#
#     Crncy        Country   Price  Quantity  Market Value
# 0     USD  United States  197.14  128379.0   25308636.06
# 1     USD  United States  120.08  392724.0   47158297.92
# 2     USD  United States  111.50  391473.0   43649239.50
# 3     USD  United States  320.73   10027.0    3215959.71
# 4     USD  United States  289.97  140604.0   40770941.88
# ..    ...            ...     ...       ...           ...
# 502   USD  United States  119.52   66518.0    7950231.36
# 503   USD  United States  487.74   11853.0    5781182.22
# 504   USD  United States  177.16   46079.0    8163355.64
# 505   USD  United States   55.80   36404.0    2031343.20
# 506   USD  United States  173.03  105338.0   18226634.14
#
# [506 rows x 8 columns]

# %%
# Use concate function to combine all dataframes.

df = pd.concat([index_LC_df, LCG_df, LCV_df, RLC_df, USSI_df])


# Column Names Clean up

df_final = df.rename(columns={'Ticker': 'ticker',
                     'Security Name' : 'security_name',
                     'Crncy' : 'currency',
                     'Country' : 'country',
                     'Price' : 'price',
                     'Quantity' : 'quantity',
                     'Market Value' : 'market_value',
                      })

# df_final.set_index('ticker')

df_final.to_csv('fund_holdings.csv')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1104 entries, 0 to 506
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fund_name      1104 non-null   object
#  1   ticker         1104 non-null   object
#  2   security_name  1104 non-null   object
#  3   currency       1104 non-null   object
#  4   country        1104 non-null   object
#  5   price          1104 non-null   float64
#  6   quantity       1104 non-null   float64
#  7   market_value   1104 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 77.6+ KB

# %%
df_final.tail()
# Out:
#                            fund_name ticker                 security_name  \
# 502  Voya U.S. Stock Index Portfolio    YUM             Yum! Brands, Inc.
# 503  Voya U.S. Stock Index Portfolio   ZBRA      Zebra Technologies Corp.
# 504  Voya U.S. Stock Index Portfolio    ZBH  Zimmer Biomet Holdings, Inc.
# 505  Voya U.S. Stock Index Portfolio   ZION              Zions Bancorp NA
# 506  Voya U.S. Stock Index Portfolio    ZTS                  Zoetis, Inc.
#
#     currency        country   price  quantity  market_value
# 502      USD  United States  119.52   66518.0    7950231.36
# 503      USD  United States  487.74   11853.0    5781182.22
# 504      USD  United States  177.16   46079.0    8163355.64
# 505      USD  United States   55.80   36404.0    2031343.20
# 506      USD  United States  173.03  105338.0   18226634.14

# %%
df_final = df_final.reset_index()
df_final = df_final[['fund_name','ticker','security_name','currency','country','price','quantity','market_value']]
df_final.tail()
# Out:
#                             fund_name ticker                 security_name  \
# 1099  Voya U.S. Stock Index Portfolio    YUM             Yum! Brands, Inc.
# 1100  Voya U.S. Stock Index Portfolio   ZBRA      Zebra Technologies Corp.
# 1101  Voya U.S. Stock Index Portfolio    ZBH  Zimmer Biomet Holdings, Inc.
# 1102  Voya U.S. Stock Index Portfolio   ZION              Zions Bancorp NA
# 1103  Voya U.S. Stock Index Portfolio    ZTS                  Zoetis, Inc.
#
#      currency        country   price  quantity  market_value
# 1099      USD  United States  119.52   66518.0    7950231.36
# 1100      USD  United States  487.74   11853.0    5781182.22
# 1101      USD  United States  177.16   46079.0    8163355.64
# 1102      USD  United States   55.80   36404.0    2031343.20
# 1103      USD  United States  173.03  105338.0   18226634.14
